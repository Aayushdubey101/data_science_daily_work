# %% [markdown]
# # 📓 Basic Array Operations
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Basic Array Operations**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Vectorized arithmetic forms the core of high-performance calculations. NumPy executes operations element-wise in compiled C code.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Element-wise math (+, -, *, /).**\n- **Vector scalars.**\n- **Unary aggregations (.sum, .mean, .max).**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Vectorized arithmetic forms the core of high-performance calculations. NumPy executes operations element-wise in compiled C code. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Assuming multiplying two 2D arrays with '*' performs matrix multiplication (it actually performs element-wise multiplication; use '@' or '.dot()' instead).
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- H\n- o\n- w\n-  \n- d\n- o\n-  \n- y\n- o\n- u\n-  \n- s\n- u\n- m\n-  \n- e\n- l\n- e\n- m\n- e\n- n\n- t\n- s\n-  \n- a\n- l\n- o\n- n\n- g\n-  \n- a\n-  \n- s\n- p\n- e\n- c\n- i\n- f\n- i\n- c\n-  \n- a\n- x\n- i\n- s\n-  \n- i\n- n\n-  \n- a\n-  \n- 2\n- D\n-  \n- a\n- r\n- r\n- a\n- y\n- ?\n-
# \n- A\n- :\n-  \n- P\n- a\n- s\n- s\n-  \n- t\n- h\n- e\n-  \n- '\n- a\n- x\n- i\n- s\n- '\n-  \n- p\n- a\n- r\n- a\n- m\n- e\n- t\n- e\n- r\n-  \n- t\n- o\n-  \n- t\n- h\n- e\n-  \n- s\n- u\n- m\n-  \n- m\n- e\n- t\n- h\n- o\n- d\n- :\n-  \n- `\n- a\n- x\n- i\n- s\n- =\n- 0\n- `\n-  \n- s\n- u\n- m\n- s\n-  \n- a\n- l\n- o\n- n\n- g\n-  \n- c\n- o\n- l\n- u\n- m\n- n\n- s\n- ,\n-  \n- w\n- h\n- i\n- l\n- e\n-  \n- `\n- a\n- x\n- i\n- s\n- =\n- 1\n- `\n-  \n- s\n- u\n- m\n- s\n-  \n- a\n- l\n- o\n- n\n- g\n-  \n- r\n- o\n- w\n- s\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Create a 2D array and calculate the mean of each row.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
a = np.array([10, 20])
b = np.array([3, 4])
print('Element-wise Add:', a + b)
print('Scalar Mult:', a * 2)
print('Sum of Elements:', a.sum())

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
