# %% [markdown]
# # 📓 Reshaping and Flattening NumPy Arrays
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Reshaping and Flattening NumPy Arrays**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Data structures must often be restructured to match model input requirements. Reshaping and flattening are essential tensor manipulation techniques.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Changing shapes with .reshape().**\n- **Flattening using .flatten() (returns a copy).**\n- **Flattening using .ravel() (returns a view).**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Data structures must often be restructured to match model input requirements. Reshaping and flattening are essential tensor manipulation techniques. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Attempting to reshape an array into dimensions that do not match the total number of elements, which raises a ValueError.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- W\n- h\n- a\n- t\n-  \n- i\n- s\n-  \n- t\n- h\n- e\n-  \n- d\n- i\n- f\n- f\n- e\n- r\n- e\n- n\n- c\n- e\n-  \n- b\n- e\n- t\n- w\n- e\n- e\n- n\n-  \n- f\n- l\n- a\n- t\n- t\n- e\n- n\n- (\n- )\n-  \n- a\n- n\n- d\n-  \n- r\n- a\n- v\n- e\n- l\n- (\n- )\n- ?\n-
# \n- A\n- :\n-  \n- f\n- l\n- a\n- t\n- t\n- e\n- n\n- (\n- )\n-  \n- a\n- l\n- w\n- a\n- y\n- s\n-  \n- r\n- e\n- t\n- u\n- r\n- n\n- s\n-  \n- a\n-  \n- n\n- e\n- w\n- ,\n-  \n- i\n- n\n- d\n- e\n- p\n- e\n- n\n- d\n- e\n- n\n- t\n-  \n- c\n- o\n- p\n- y\n-  \n- o\n- f\n-  \n- t\n- h\n- e\n-  \n- a\n- r\n- r\n- a\n- y\n-  \n- i\n- n\n-  \n- m\n- e\n- m\n- o\n- r\n- y\n- .\n-  \n- r\n- a\n- v\n- e\n- l\n- (\n- )\n-  \n- r\n- e\n- t\n- u\n- r\n- n\n- s\n-  \n- a\n-  \n- f\n- l\n- a\n- t\n- t\n- e\n- n\n- e\n- d\n-  \n- v\n- i\n- e\n- w\n-  \n- o\n- f\n-  \n- t\n- h\n- e\n-  \n- o\n- r\n- i\n- g\n- i\n- n\n- a\n- l\n-  \n- a\n- r\n- r\n- a\n- y\n- ,\n-  \n- a\n- v\n- o\n- i\n- d\n- i\n- n\n- g\n-  \n- m\n- e\n- m\n- o\n- r\n- y\n-  \n- c\n- o\n- p\n- y\n-  \n- o\n- v\n- e\n- r\n- h\n- e\n- a\n- d\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Reshape a 1D array of 12 elements into a 3x4 matrix, then flatten it back using ravel.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
arr = np.arange(6)
reshaped = arr.reshape((2, 3))
print('Reshaped (2, 3):\n', reshaped)
print('Ravel view:', reshaped.ravel())

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
