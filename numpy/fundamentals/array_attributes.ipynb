# %% [markdown]
# # 📓 NumPy Array Attributes
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **NumPy Array Attributes**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Inspecting array dimensions, shapes, and data types is crucial when preparing matrices for neural networks and machine learning pipelines.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **ndim (number of dimensions).**\n- **shape (tuple of array dimensions).**\n- **dtype (data type of array elements).**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Inspecting array dimensions, shapes, and data types is crucial when preparing matrices for neural networks and machine learning pipelines. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Confusing the shape attribute (tuple) with ndim (integer), leading to dimension mismatch errors.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- H\n- o\n- w\n-  \n- d\n- o\n-  \n- y\n- o\n- u\n-  \n- c\n- h\n- a\n- n\n- g\n- e\n-  \n- t\n- h\n- e\n-  \n- d\n- a\n- t\n- a\n-  \n- t\n- y\n- p\n- e\n-  \n- o\n- f\n-  \n- a\n- n\n-  \n- e\n- x\n- i\n- s\n- t\n- i\n- n\n- g\n-  \n- N\n- u\n- m\n- P\n- y\n-  \n- a\n- r\n- r\n- a\n- y\n- ?\n-
# \n- A\n- :\n-  \n- U\n- s\n- e\n-  \n- t\n- h\n- e\n-  \n- '\n- .\n- a\n- s\n- t\n- y\n- p\n- e\n- (\n- )\n- '\n-  \n- m\n- e\n- t\n- h\n- o\n- d\n-  \n- (\n- e\n- .\n- g\n- .\n-  \n- a\n- r\n- r\n- .\n- a\n- s\n- t\n- y\n- p\n- e\n- (\n- n\n- p\n- .\n- i\n- n\n- t\n- 3\n- 2\n- )\n- )\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Create a 2D array and print its shape, dimensions, size, and data type.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
arr = np.array([[1.0, 2.0], [3.0, 4.0]])
print('Dimensions (ndim):', arr.ndim)
print('Shape:', arr.shape)
print('Data type (dtype):', arr.dtype)

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
