# %% [markdown]
# # 📓 Introduction to NumPy Arrays
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Introduction to NumPy Arrays**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# NumPy is the foundational library for scientific computing in Python. It provides high-performance, contiguous C-level arrays that are up to 100x faster than standard Python lists.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **ND-array creation.**\n- **Performance comparison with Python lists.**\n- **Contiguous memory layout.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# NumPy is the foundational library for scientific computing in Python. It provides high-performance, contiguous C-level arrays that are up to 100x faster than standard Python lists. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Iterating over NumPy arrays using standard Python loops instead of vectorized operations, which defeats their performance benefits.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- W\n- h\n- y\n-  \n- a\n- r\n- e\n-  \n- N\n- u\n- m\n- P\n- y\n-  \n- a\n- r\n- r\n- a\n- y\n- s\n-  \n- f\n- a\n- s\n- t\n- e\n- r\n-  \n- t\n- h\n- a\n- n\n-  \n- P\n- y\n- t\n- h\n- o\n- n\n-  \n- l\n- i\n- s\n- t\n- s\n- ?\n-
# \n- A\n- :\n-  \n- N\n- u\n- m\n- P\n- y\n-  \n- a\n- r\n- r\n- a\n- y\n- s\n-  \n- s\n- t\n- o\n- r\n- e\n-  \n- e\n- l\n- e\n- m\n- e\n- n\n- t\n- s\n-  \n- i\n- n\n-  \n- c\n- o\n- n\n- t\n- i\n- g\n- u\n- o\n- u\n- s\n-  \n- b\n- l\n- o\n- c\n- k\n- s\n-  \n- o\n- f\n-  \n- m\n- e\n- m\n- o\n- r\n- y\n-  \n- a\n- n\n- d\n-  \n- h\n- a\n- v\n- e\n-  \n- u\n- n\n- i\n- f\n- o\n- r\n- m\n-  \n- d\n- a\n- t\n- a\n-  \n- t\n- y\n- p\n- e\n- s\n- ,\n-  \n- a\n- l\n- l\n- o\n- w\n- i\n- n\n- g\n-  \n- o\n- p\n- e\n- r\n- a\n- t\n- i\n- o\n- n\n- s\n-  \n- t\n- o\n-  \n- b\n- e\n-  \n- e\n- x\n- e\n- c\n- u\n- t\n- e\n- d\n-  \n- i\n- n\n-  \n- c\n- o\n- m\n- p\n- i\n- l\n- e\n- d\n-  \n- C\n-  \n- c\n- o\n- d\n- e\n-  \n- a\n- n\n- d\n-  \n- l\n- e\n- v\n- e\n- r\n- a\n- g\n- i\n- n\n- g\n-  \n- v\n- e\n- c\n- t\n- o\n- r\n- i\n- z\n- a\n- t\n- i\n- o\n- n\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Create a 3x3 array containing numbers from 0 to 8 using np.arange and np.reshape.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
# Creation from list
arr = np.array([1, 2, 3])
print('Array:', arr)
# Zero and one helpers
print('Zeros:', np.zeros((2, 2)))
print('Ones:', np.ones((2, 3)))
# Out:
# Array: [1 2 3]
# Zeros: [[0. 0.]
#  [0. 0.]]
# Ones: [[1. 1. 1.]
#  [1. 1. 1.]]

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
