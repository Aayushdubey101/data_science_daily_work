# %% [markdown]
# # 📓 Fancy Indexing and Coordinate Selection
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Fancy Indexing and Coordinate Selection**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Fancy indexing allows selecting complex, non-contiguous subsets of data using coordinate lists.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Integer array indexing.**\n- **Selecting specific rows and columns.**\n- **Fancy indexing returns copies, not views.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Fancy indexing allows selecting complex, non-contiguous subsets of data using coordinate lists. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Assuming fancy indexing returns a view of the original array (it always returns an independent copy, unlike basic slicing).
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- D\n- o\n- e\n- s\n-  \n- f\n- a\n- n\n- c\n- y\n-  \n- i\n- n\n- d\n- e\n- x\n- i\n- n\n- g\n-  \n- r\n- e\n- t\n- u\n- r\n- n\n-  \n- a\n-  \n- v\n- i\n- e\n- w\n-  \n- o\n- r\n-  \n- a\n-  \n- c\n- o\n- p\n- y\n- ?\n-
# \n- A\n- :\n-  \n- I\n- t\n-  \n- a\n- l\n- w\n- a\n- y\n- s\n-  \n- r\n- e\n- t\n- u\n- r\n- n\n- s\n-  \n- a\n-  \n- c\n- o\n- p\n- y\n- ,\n-  \n- s\n- o\n-  \n- m\n- o\n- d\n- i\n- f\n- y\n- i\n- n\n- g\n-  \n- t\n- h\n- e\n-  \n- r\n- e\n- s\n- u\n- l\n- t\n-  \n- d\n- o\n- e\n- s\n-  \n- n\n- o\n- t\n-  \n- a\n- f\n- f\n- e\n- c\n- t\n-  \n- t\n- h\n- e\n-  \n- o\n- r\n- i\n- g\n- i\n- n\n- a\n- l\n-  \n- a\n- r\n- r\n- a\n- y\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Use fancy indexing to extract the corners of a 4x4 matrix.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50])
indices = [0, 2, 4]
print('Fancy Index Output:', arr[indices])

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
