# %% [markdown]
# # 📓 Handling Missing Values and NaNs
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Handling Missing Values and NaNs**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Real-world data is messy. Dealing with missing values (NaNs) and infs is a crucial preprocessing step.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Representation of missing values using np.nan.**\n- **Detecting NaNs using np.isnan().**\n- **Masking and replacing missing elements.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Real-world data is messy. Dealing with missing values (NaNs) and infs is a crucial preprocessing step. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Comparing a variable to NaN directly using `x == np.nan` (this always evaluates to False; use `np.isnan(x)` instead).
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- W\n- h\n- y\n-  \n- d\n- o\n- e\n- s\n-  \n- '\n- n\n- p\n- .\n- n\n- a\n- n\n-  \n- =\n- =\n-  \n- n\n- p\n- .\n- n\n- a\n- n\n- '\n-  \n- e\n- v\n- a\n- l\n- u\n- a\n- t\n- e\n-  \n- t\n- o\n-  \n- F\n- a\n- l\n- s\n- e\n- ?\n-
# \n- A\n- :\n-  \n- N\n- a\n- N\n-  \n- r\n- e\n- p\n- r\n- e\n- s\n- e\n- n\n- t\n- s\n-  \n- a\n- n\n-  \n- u\n- n\n- d\n- e\n- f\n- i\n- n\n- e\n- d\n-  \n- n\n- u\n- m\n- e\n- r\n- i\n- c\n- a\n- l\n-  \n- v\n- a\n- l\n- u\n- e\n- ,\n-  \n- a\n- n\n- d\n-  \n- b\n- y\n-  \n- d\n- e\n- f\n- i\n- n\n- i\n- t\n- i\n- o\n- n\n- ,\n-  \n- a\n- n\n-  \n- u\n- n\n- d\n- e\n- f\n- i\n- n\n- e\n- d\n-  \n- v\n- a\n- l\n- u\n- e\n-  \n- c\n- a\n- n\n- n\n- o\n- t\n-  \n- b\n- e\n-  \n- e\n- q\n- u\n- a\n- l\n-  \n- t\n- o\n-  \n- a\n- n\n- o\n- t\n- h\n- e\n- r\n-  \n- u\n- n\n- d\n- e\n- f\n- i\n- n\n- e\n- d\n-  \n- v\n- a\n- l\n- u\n- e\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Create an array with NaNs, replace all NaNs with the mean of the non-NaN elements.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
arr = np.array([1.0, np.nan, 3.0])
print('Is NaN mask:', np.isnan(arr))
print('Sum ignoring NaNs:', np.nansum(arr))

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
