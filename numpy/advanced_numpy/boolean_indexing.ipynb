# %% [markdown]
# # 📓 Boolean Indexing and Logical Masks
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Boolean Indexing and Logical Masks**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Filtering datasets based on conditional criteria is a fundamental task. Boolean masks extract elements that satisfy logical criteria.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Creating boolean conditions.**\n- **Filtering arrays using boolean masks.**\n- **Combining conditions with bitwise operators (&, |).**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Filtering datasets based on conditional criteria is a fundamental task. Boolean masks extract elements that satisfy logical criteria. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Using logical keywords 'and' / 'or' inside boolean filters instead of bitwise operators '&' / '|', raising a ValueError.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- W\n- h\n- y\n-  \n- m\n- u\n- s\n- t\n-  \n- y\n- o\n- u\n-  \n- u\n- s\n- e\n-  \n- '\n- &\n- '\n-  \n- a\n- n\n- d\n-  \n- '\n- |\n- '\n-  \n- i\n- n\n- s\n- t\n- e\n- a\n- d\n-  \n- o\n- f\n-  \n- '\n- a\n- n\n- d\n- '\n-  \n- a\n- n\n- d\n-  \n- '\n- o\n- r\n- '\n-  \n- f\n- o\n- r\n-  \n- e\n- l\n- e\n- m\n- e\n- n\n- t\n- -\n- w\n- i\n- s\n- e\n-  \n- b\n- o\n- o\n- l\n- e\n- a\n- n\n-  \n- o\n- p\n- e\n- r\n- a\n- t\n- i\n- o\n- n\n- s\n- ?\n-
# \n- A\n- :\n-  \n- '\n- a\n- n\n- d\n- '\n-  \n- a\n- n\n- d\n-  \n- '\n- o\n- r\n- '\n-  \n- e\n- v\n- a\n- l\n- u\n- a\n- t\n- e\n-  \n- t\n- h\n- e\n-  \n- t\n- r\n- u\n- t\n- h\n-  \n- v\n- a\n- l\n- u\n- e\n-  \n- o\n- f\n-  \n- t\n- h\n- e\n-  \n- e\n- n\n- t\n- i\n- r\n- e\n-  \n- o\n- b\n- j\n- e\n- c\n- t\n- ,\n-  \n- w\n- h\n- e\n- r\n- e\n- a\n- s\n-  \n- '\n- &\n- '\n-  \n- a\n- n\n- d\n-  \n- '\n- |\n- '\n-  \n- p\n- e\n- r\n- f\n- o\n- r\n- m\n-  \n- e\n- l\n- e\n- m\n- e\n- n\n- t\n- -\n- w\n- i\n- s\n- e\n-  \n- c\n- o\n- m\n- p\n- a\n- r\n- i\n- s\n- o\n- n\n- s\n-  \n- a\n- c\n- r\n- o\n- s\n- s\n-  \n- t\n- h\n- e\n-  \n- a\n- r\n- r\n- a\n- y\n- s\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Filter out all odd numbers from an array of integers.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
mask = arr > 3
print('Mask:', mask)
print('Filtered Array:', arr[mask])

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
