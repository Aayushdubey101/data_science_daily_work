# %% [markdown]
# # 📓 Advanced Slicing and Views vs Copies
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Advanced Slicing and Views vs Copies**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Understanding how NumPy slices data without allocating new memory is essential to prevent accidental mutations on shared arrays.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Multi-dimensional slicing.**\n- **Strides and memory layouts.**\n- **Views vs deep copies.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Understanding how NumPy slices data without allocating new memory is essential to prevent accidental mutations on shared arrays. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Modifying a sliced array and accidentally mutating the original array because slices are views, not independent copies.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- H\n- o\n- w\n-  \n- d\n- o\n-  \n- y\n- o\n- u\n-  \n- f\n- o\n- r\n- c\n- e\n-  \n- a\n-  \n- s\n- l\n- i\n- c\n- e\n-  \n- t\n- o\n-  \n- b\n- e\n-  \n- a\n-  \n- c\n- o\n- p\n- y\n-  \n- i\n- n\n- s\n- t\n- e\n- a\n- d\n-  \n- o\n- f\n-  \n- a\n-  \n- v\n- i\n- e\n- w\n- ?\n-
# \n- A\n- :\n-  \n- C\n- a\n- l\n- l\n-  \n- t\n- h\n- e\n-  \n- '\n- .\n- c\n- o\n- p\n- y\n- (\n- )\n- '\n-  \n- m\n- e\n- t\n- h\n- o\n- d\n-  \n- e\n- x\n- p\n- l\n- i\n- c\n- i\n- t\n- l\n- y\n-  \n- o\n- n\n-  \n- t\n- h\n- e\n-  \n- s\n- l\n- i\n- c\n- e\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Extract a 2x2 sub-matrix from a 4x4 matrix and ensure modifying the sub-matrix does not alter the original.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
arr = np.array([[1, 2, 3], [4, 5, 6]])
slice_view = arr[:, 1:3]
print('Slice View:\n', slice_view)
slice_view[0, 0] = 99
print('Original modified via view:\n', arr)

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
