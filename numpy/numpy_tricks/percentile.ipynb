# %% [markdown]
# # 📓 Statistical Computations and Percentiles
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Statistical Computations and Percentiles**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Calculating statistics like percentiles, medians, and standard deviations is the starting point of exploratory data analysis.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Percentiles using np.percentile().**\n- **Calculating medians and standard deviations.**\n- **Aggregating metrics along axes.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Calculating statistics like percentiles, medians, and standard deviations is the starting point of exploratory data analysis. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Calculating statistics on arrays containing NaNs, which returns NaN (use `np.nanpercentile()` or `np.nanmedian()` to ignore NaNs).
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- H\n- o\n- w\n-  \n- d\n- o\n-  \n- y\n- o\n- u\n-  \n- c\n- a\n- l\n- c\n- u\n- l\n- a\n- t\n- e\n-  \n- t\n- h\n- e\n-  \n- 7\n- 5\n- t\n- h\n-  \n- p\n- e\n- r\n- c\n- e\n- n\n- t\n- i\n- l\n- e\n-  \n- o\n- f\n-  \n- a\n- n\n-  \n- a\n- r\n- r\n- a\n- y\n-  \n- i\n- n\n-  \n- N\n- u\n- m\n- P\n- y\n- ?\n-
# \n- A\n- :\n-  \n- U\n- s\n- e\n-  \n- t\n- h\n- e\n-  \n- `\n- n\n- p\n- .\n- p\n- e\n- r\n- c\n- e\n- n\n- t\n- i\n- l\n- e\n- (\n- a\n- r\n- r\n- ,\n-  \n- 7\n- 5\n- )\n- `\n-  \n- f\n- u\n- n\n- c\n- t\n- i\n- o\n- n\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Calculate the 25th, 50th, and 75th percentiles of a list of housing prices.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import numpy as np
scores = np.array([50, 60, 70, 80, 90, 100])
print('Median score:', np.median(scores))
print('90th Percentile:', np.percentile(scores, 90))

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
