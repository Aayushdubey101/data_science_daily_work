# %% [markdown]
# # 📓 Concatenating and Stacking Datasets
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Concatenating and Stacking Datasets**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Stacking datasets vertically (appending rows) or horizontally (appending columns) is a common datastep.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Vertical concatenation along rows (axis=0).**\n- **Horizontal concatenation along columns (axis=1).**\n- **Handling non-overlapping indexes during alignment.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Stacking datasets vertically (appending rows) or horizontally (appending columns) is a common datastep. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Concatenating dataframes with different column sets vertically, which fills the missing entries with NaN and wastes memory.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- W\n- h\n- a\n- t\n-  \n- p\n- a\n- r\n- a\n- m\n- e\n- t\n- e\n- r\n-  \n- c\n- o\n- n\n- t\n- r\n- o\n- l\n- s\n-  \n- w\n- h\n- e\n- t\n- h\n- e\n- r\n-  \n- p\n- d\n- .\n- c\n- o\n- n\n- c\n- a\n- t\n-  \n- m\n- e\n- r\n- g\n- e\n- s\n-  \n- t\n- a\n- b\n- l\n- e\n- s\n-  \n- h\n- o\n- r\n- i\n- z\n- o\n- n\n- t\n- a\n- l\n- l\n- y\n-  \n- o\n- r\n-  \n- v\n- e\n- r\n- t\n- i\n- c\n- a\n- l\n- l\n- y\n- ?\n-
# \n- A\n- :\n-  \n- T\n- h\n- e\n-  \n- '\n- a\n- x\n- i\n- s\n- '\n-  \n- p\n- a\n- r\n- a\n- m\n- e\n- t\n- e\n- r\n-  \n- (\n- a\n- x\n- i\n- s\n- =\n- 0\n-  \n- f\n- o\n- r\n-  \n- v\n- e\n- r\n- t\n- i\n- c\n- a\n- l\n-  \n- r\n- o\n- w\n- s\n- ,\n-  \n- a\n- x\n- i\n- s\n- =\n- 1\n-  \n- f\n- o\n- r\n-  \n- h\n- o\n- r\n- i\n- z\n- o\n- n\n- t\n- a\n- l\n-  \n- c\n- o\n- l\n- u\n- m\n- n\n- s\n- )\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Concatenate three separate monthly sales dataframes vertically, ignoring original indexes.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import pandas as pd
s1 = pd.Series([10, 20])
s2 = pd.Series([30, 40])
print('Concatenated vertically:\n', pd.concat([s1, s2], axis=0))
print('Concatenated horizontally:\n', pd.concat([s1, s2], axis=1))

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
