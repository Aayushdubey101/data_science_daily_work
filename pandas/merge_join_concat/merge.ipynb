# %% [markdown]
# # 📓 Relational Joins and Merges
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Relational Joins and Merges**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Combining tables using database-style keys is essential when working with normalized datasets.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Inner, outer, left, and right merges.**\n- **Merging on single and multiple keys.**\n- **Handling overlapping column names with suffixes.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Combining tables using database-style keys is essential when working with normalized datasets. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Merging on mismatching key names without specifying `left_on` and `right_on`, which raises a KeyError.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- W\n- h\n- a\n- t\n-  \n- a\n- r\n- e\n-  \n- t\n- h\n- e\n-  \n- f\n- o\n- u\n- r\n-  \n- m\n- a\n- i\n- n\n-  \n- j\n- o\n- i\n- n\n-  \n- t\n- y\n- p\n- e\n- s\n-  \n- s\n- u\n- p\n- p\n- o\n- r\n- t\n- e\n- d\n-  \n- b\n- y\n-  \n- p\n- d\n- .\n- m\n- e\n- r\n- g\n- e\n- ?\n-
# \n- A\n- :\n-  \n- '\n- i\n- n\n- n\n- e\n- r\n- '\n-  \n- (\n- i\n- n\n- t\n- e\n- r\n- s\n- e\n- c\n- t\n- i\n- o\n- n\n-  \n- o\n- f\n-  \n- k\n- e\n- y\n- s\n- )\n- ,\n-  \n- '\n- o\n- u\n- t\n- e\n- r\n- '\n-  \n- (\n- u\n- n\n- i\n- o\n- n\n-  \n- o\n- f\n-  \n- k\n- e\n- y\n- s\n- )\n- ,\n-  \n- '\n- l\n- e\n- f\n- t\n- '\n-  \n- (\n- a\n- l\n- l\n-  \n- k\n- e\n- y\n- s\n-  \n- f\n- r\n- o\n- m\n-  \n- l\n- e\n- f\n- t\n- )\n- ,\n-  \n- a\n- n\n- d\n-  \n- '\n- r\n- i\n- g\n- h\n- t\n- '\n-  \n- (\n- a\n- l\n- l\n-  \n- k\n- e\n- y\n- s\n-  \n- f\n- r\n- o\n- m\n-  \n- r\n- i\n- g\n- h\n- t\n- )\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Perform an outer merge on two dataframes of client details, combining records on their email address.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import pandas as pd
df1 = pd.DataFrame({'ID': [1, 2], 'Name': ['Aayush', 'Bob']})
df2 = pd.DataFrame({'ID': [1, 3], 'Salary': [100, 150]})
merged = pd.merge(df1, df2, on='ID', how='inner')
print('Inner Merge:\n', merged)

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
