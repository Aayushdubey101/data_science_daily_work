# %% [markdown]
# # 📓 Index-Based Merging and Joins
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Index-Based Merging and Joins**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Merging tables on their indexes is faster and cleaner than merging on columns.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Merging on index constraints.**\n- **Comparing .join() with pd.merge().**\n- **Performing multi-index joins.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Merging tables on their indexes is faster and cleaner than merging on columns. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Calling `.join()` on columns containing identical names without specifying `lsuffix` and `rsuffix` parameters, causing a ValueError.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- H\n- o\n- w\n-  \n- d\n- o\n- e\n- s\n-  \n- t\n- h\n- e\n-  \n- j\n- o\n- i\n- n\n-  \n- m\n- e\n- t\n- h\n- o\n- d\n-  \n- d\n- i\n- f\n- f\n- e\n- r\n-  \n- f\n- r\n- o\n- m\n-  \n- m\n- e\n- r\n- g\n- e\n- ?\n-
# \n- A\n- :\n-  \n- j\n- o\n- i\n- n\n-  \n- i\n- s\n-  \n- o\n- p\n- t\n- i\n- m\n- i\n- z\n- e\n- d\n-  \n- t\n- o\n-  \n- c\n- o\n- m\n- b\n- i\n- n\n- e\n-  \n- t\n- a\n- b\n- l\n- e\n- s\n-  \n- o\n- n\n-  \n- t\n- h\n- e\n- i\n- r\n-  \n- i\n- n\n- d\n- e\n- x\n-  \n- k\n- e\n- y\n- s\n-  \n- b\n- y\n-  \n- d\n- e\n- f\n- a\n- u\n- l\n- t\n- ,\n-  \n- w\n- h\n- e\n- r\n- e\n- a\n- s\n-  \n- m\n- e\n- r\n- g\n- e\n-  \n- c\n- o\n- m\n- b\n- i\n- n\n- e\n- s\n-  \n- t\n- a\n- b\n- l\n- e\n- s\n-  \n- o\n- n\n-  \n- s\n- p\n- e\n- c\n- i\n- f\n- i\n- c\n-  \n- c\n- o\n- l\n- u\n- m\n- n\n-  \n- c\n- o\n- l\n- u\n- m\n- n\n- s\n-  \n- b\n- y\n-  \n- d\n- e\n- f\n- a\n- u\n- l\n- t\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Combine two customer tables on their primary index key using left join.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import pandas as pd
df1 = pd.DataFrame({'Name': ['Aayush', 'Bob']}, index=[1, 2])
df2 = pd.DataFrame({'Salary': [100, 150]}, index=[1, 3])
joined = df1.join(df2, how='left')
print('Left Join:\n', joined)

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
