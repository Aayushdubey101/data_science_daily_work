# %% [markdown]
# # 📓 Adding Columns and Feature Engineering
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Adding Columns and Feature Engineering**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Feature engineering requires creating columns, modifying existing attributes, and applying mathematical formulas.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Creating columns from arithmetic operations.**\n- **Using the .assign() helper.**\n- **Modifying existing columns in-place.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Feature engineering requires creating columns, modifying existing attributes, and applying mathematical formulas. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Creating columns using chained indexing `df[cond]['col'] = val` which raises a SettingWithCopyWarning and may fail to update the original DataFrame.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- W\n- h\n- a\n- t\n-  \n- w\n- a\n- r\n- n\n- i\n- n\n- g\n-  \n- d\n- o\n- e\n- s\n-  \n- P\n- a\n- n\n- d\n- a\n- s\n-  \n- r\n- a\n- i\n- s\n- e\n-  \n- d\n- u\n- r\n- i\n- n\n- g\n-  \n- c\n- h\n- a\n- i\n- n\n- e\n- d\n-  \n- a\n- s\n- s\n- i\n- g\n- n\n- m\n- e\n- n\n- t\n- s\n- ?\n-
# \n- A\n- :\n-  \n- S\n- e\n- t\n- t\n- i\n- n\n- g\n- W\n- i\n- t\n- h\n- C\n- o\n- p\n- y\n- W\n- a\n- r\n- n\n- i\n- n\n- g\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Create a column representing a formatted category flag based on numerical thresholds of another column.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import pandas as pd
df = pd.DataFrame({'Price': [100, 200]})
df['Tax'] = df['Price'] * 0.1
print('DataFrame with Tax:\n', df)

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
