# %% [markdown]
# # 📓 Advanced Row Filtering using loc and iloc
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Advanced Row Filtering using loc and iloc**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# Querying subsets of rows and columns requires mastering label-based loc and coordinate-based iloc selections.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **Label-based selection with .loc[].**\n- **Position-based selection with .iloc[].**\n- **Multi-conditional index filtering.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# Querying subsets of rows and columns requires mastering label-based loc and coordinate-based iloc selections. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Forgetting that slicing with `.loc[]` is inclusive of the stop boundary, whereas slicing with `.iloc[]` is exclusive.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- E\n- x\n- p\n- l\n- a\n- i\n- n\n-  \n- t\n- h\n- e\n-  \n- d\n- i\n- f\n- f\n- e\n- r\n- e\n- n\n- c\n- e\n-  \n- b\n- e\n- t\n- w\n- e\n- e\n- n\n-  \n- l\n- o\n- c\n-  \n- a\n- n\n- d\n-  \n- i\n- l\n- o\n- c\n- .\n-
# \n- A\n- :\n-  \n- l\n- o\n- c\n-  \n- i\n- s\n-  \n- l\n- a\n- b\n- e\n- l\n- -\n- b\n- a\n- s\n- e\n- d\n-  \n- (\n- t\n- a\n- k\n- e\n- s\n-  \n- s\n- t\n- r\n- i\n- n\n- g\n-  \n- k\n- e\n- y\n- s\n- ,\n-  \n- i\n- n\n- c\n- l\n- u\n- s\n- i\n- v\n- e\n-  \n- s\n- t\n- o\n- p\n-  \n- b\n- o\n- u\n- n\n- d\n- s\n- )\n- .\n-  \n- i\n- l\n- o\n- c\n-  \n- i\n- s\n-  \n- i\n- n\n- t\n- e\n- g\n- e\n- r\n-  \n- p\n- o\n- s\n- i\n- t\n- i\n- o\n- n\n- -\n- b\n- a\n- s\n- e\n- d\n-  \n- (\n- t\n- a\n- k\n- e\n- s\n-  \n- z\n- e\n- r\n- o\n- -\n- b\n- a\n- s\n- e\n- d\n-  \n- i\n- n\n- t\n- e\n- g\n- e\n- r\n-  \n- i\n- n\n- d\n- i\n- c\n- e\n- s\n- ,\n-  \n- e\n- x\n- c\n- l\n- u\n- s\n- i\n- v\n- e\n-  \n- s\n- t\n- o\n- p\n-  \n- b\n- o\n- u\n- n\n- d\n- s\n- )\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Use loc to filter rows where a condition is met and extract only two specific columns.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import pandas as pd
df = pd.DataFrame({'Val': [10, 20, 30]}, index=['a', 'b', 'c'])
print('loc b:\n', df.loc['b'])
print('iloc 1:\n', df.iloc[1])

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
