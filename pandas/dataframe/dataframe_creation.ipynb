# %% [markdown]
# # 📓 Dataframe Creation and Attributes
#
# ---
#
# ## 🔍 1. Topic Overview
# Welcome to this in-depth study guide on **Dataframe Creation and Attributes**! In this notebook, we explore the core mental models, standard syntax guidelines, and high-performance execution patterns surrounding this topic.
#
# ---
#
# ## 💡 2. Why This Topic Matters
# DataFrames represent 2D labeled tabular structures. Learning how to create DataFrames from scratch and inspect their properties is essential.
#
# ---
#
# ## 🧠 3. Core Concepts
# Here are the essential terms and key pillars to master:
# - **DataFrame creation from lists, dicts, arrays.**\n- **Inspecting shapes, columns, and indexes.**\n- **The index-based data model.**
#
# ---
#
# ## 📝 4. Detailed Explanations
# DataFrames represent 2D labeled tabular structures. Learning how to create DataFrames from scratch and inspect their properties is essential. Vectorized methods execute in compiled C routines underneath, which dramatically accelerates speed.
#
# ---
#
# ## ⚠️ 8. Common Mistakes & Pitfalls
# Be on the lookout for these frequent errors:
# - **Pitfall:** Passing mismatched list lengths to dictionary builders, causing a ValueError during instantiation.
#
# ---
#
# ## 💼 9. Interview Questions
# Expected conceptual and coding questions in technical interviews:
# - Q\n- :\n-  \n- H\n- o\n- w\n-  \n- d\n- o\n-  \n- y\n- o\n- u\n-  \n- c\n- h\n- e\n- c\n- k\n-  \n- t\n- h\n- e\n-  \n- r\n- o\n- w\n-  \n- i\n- n\n- d\n- e\n- x\n-  \n- l\n- a\n- b\n- e\n- l\n- s\n-  \n- a\n- n\n- d\n-  \n- c\n- o\n- l\n- u\n- m\n- n\n-  \n- n\n- a\n- m\n- e\n- s\n-  \n- o\n- f\n-  \n- a\n-  \n- D\n- a\n- t\n- a\n- F\n- r\n- a\n- m\n- e\n- ?\n-
# \n- A\n- :\n-  \n- U\n- s\n- e\n-  \n- t\n- h\n- e\n-  \n- `\n- d\n- f\n- .\n- i\n- n\n- d\n- e\n- x\n- `\n-  \n- a\n- n\n- d\n-  \n- `\n- d\n- f\n- .\n- c\n- o\n- l\n- u\n- m\n- n\n- s\n- `\n-  \n- a\n- t\n- t\n- r\n- i\n- b\n- u\n- t\n- e\n- s\n- .
#
# ---
#
# ## 📝 10. Practice Questions
# Sharpen your skills with these hands-on exercises:
# - **Task:** Create a DataFrame from a 2D NumPy array of random numbers, naming columns 'X', 'Y', 'Z'.
#
# ---
#
# ## 🎯 11. Summary & Action Items
# *   Understand the core mental model and constraints.
# *   Avoid standard anti-patterns and performance traps.
# *   Practice the exercises to build strong muscle memory.

# %% [markdown]
# ---
#
# ## 💻 5. Multiple Code Examples & Real-world Scenarios
# Below are clean, commented execution examples demonstrating the concepts in action:

# %%
import pandas as pd
data = {'Name': ['Aayush', 'Bob'], 'Age': [25, 30]}
df = pd.DataFrame(data)
print('DataFrame:\n', df)
print('Columns:', df.columns)

# %% [markdown]
# ---
#
# ## 📝 7. Personal Notes & Key Takeaways
# > ✍️ **Student Takeaway:** Always think about memory efficiency and time complexity.
# > *   Double-check references and memory addresses when copying mutable collections.
# > *   Prefer vectorized libraries and native functional protocols over manual loops.
