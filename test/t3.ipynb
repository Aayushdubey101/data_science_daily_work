# %% [markdown]
# # Vectorised operations in Pandas
#
# ```python

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
ti=pd.read_csv(r'E:\Cursor_DATA\python_data\csv_data\datasets-session-22\titanic.csv')
exp=pd.read_csv(r"E:\Cursor_DATA\python_data\csv_data\datasets-session-22\expense_data.csv")

# %%
# vectorised operations in pandas
x=np.array([1,2,3,4])
x**2# this is called vectorised operation
# Out:
# array([ 1,  4,  9, 16])

# %% [markdown]
# # vectorised operations by stringa

# %%
l=['cat','cash','dog','cate','dog']
[i.startswith('c') for i in l]# this is not vectorised operation
# Out:
# [True, True, False, True, False]

# %%
l=['cat','cash','dog','cate',None]
[i.startswith('c') for i in l]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 l=['cat','cash','dog','cate',None]
# ----> 2 [i.startswith('c') for i in l]
#
# AttributeError: 'NoneType' object has no attribute 'startswith'

# %%
# soluthion of above problem used pabdas vectorised operation
df=pd.Series(l)
df.str.startswith('c')
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ti['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
ti['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
ti['Name'].str.len()
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name, Length: 891, dtype: int64

# %%
# getting largest name length
ti['Name'].str.len().max()
# Out:
# np.int64(82)

# %%
ti['Name'][ti['Name'].str.len() == ti['Name'].str.len().max()].values[0]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
ti['Name'].str.strip()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
x=ti['Name'].str.strip(",")
# x.str.len().max()
x
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
x=ti['Name'].str.split(",")
x[1]
# Out:
# ['Cumings', ' Mrs. John Bradley (Florence Briggs Thayer)']

# %%
y=x.str.get(1)
ti['Last_Name']=x.str.get(0)
ti
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
y
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
y
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 886                                    Rev. Juozas
# 887                           Miss. Margaret Edith
# 888                 Miss. Catherine Helen "Carrie"
# 889                                Mr. Karl Howell
# 890                                    Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
ti[['Title','First_Name']]=y.str.strip().str.split(" ",n=1,expand=True)

# %%
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ti['Title'].value_counts()
# Out:
# Title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Mlle.          2
# Major.         2
# Ms.            1
# Mme.           1
# Don.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
ti['Title']=ti['Title'].replace(['Ms.','Mlle.','Mme.'],'Miss.')

# %%
ti['Title'].value_counts()
# Out:
# Title
# Mr.          517
# Miss.        186
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Col.           2
# Major.         2
# Don.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
# get data of those passengers whose name has john in it
ti[ti['First_Name'].str.contains('John')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# 550          551         1       1
# 563          564         0       3
# 572          573         1       1
# ...

# %%
# get data whose name contains vowel ether firstletter or last letter
ti[ti['First_Name'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$',regex=True)]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 16            17         0       3                   Rice, Master. Eugene
# 38            39         0       3     Vander Planke, Miss. Augusta Maria
# 61            62         1       1                    Icard, Miss. Amelie
# 64            65         0       1                  Stewart, Mr. Albert A
# 68            69         1       3        Andersson, Miss. Erna Alexandra
# 80            81         0       3                   Waelens, Mr. Achille
# 106          107         1       3       Salkjelsvik, Miss. Anna Kristine
# 119          120         0       3      Andersson, Miss. Ellis Anna Maria
# 128          129         1       3                      Peter, Miss. Anna
# 135          136         0       2                     Richard, Mr. Emile
# 141          142         1       3               Nysten, Miss. Anna Sofia
# 152          153         0       3                       Meo, Mr. Alfonzo
# ...

# %%
# get data whose name contains vowel ether firstletter or last letter
ti[ti['Last_Name'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$',regex=True)]
# Out:
#      PassengerId  Survived  Pclass  \
# 30            31         0       1
# 49            50         0       3
# 207          208         1       3
# 210          211         0       3
# 353          354         0       3
# 493          494         0       1
# 518          519         1       2
# 784          785         0       3
# 840          841         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 207                        Albimona, Mr. Nassef Cassem    male  26.0      0
# 210                                     Ali, Mr. Ahmed    male  24.0      0
# 353                          Arnold-Franchi, Mr. Josef    male  25.0      1
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# ...

# %%
# perform slicing
ti
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ti['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# ## this is slicing concept

# %%
ti['Name'].str[1::2]
# Out:
# 0                    rud r wnHri
# 1      uig,Ms onBaly(lrneBig hyr
# 2                    ekie,Ms.Lia
# 3         urle r.JcusHah(iyMyPe)
# 4                   le,M.WlimHny
#                  ...
# 886                   otia e.Joa
# 887               rhm is agrtEih
# 888         ontn is ahrn ee Cri"
# 889                   er r alHwl
# 890                    oly r arc
# Name: Name, Length: 891, dtype: object
