# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
ti=pd.read_csv(r'E:\Cursor_DATA\python_data\csv_data\datasets-session-22\titanic.csv')
exp=pd.read_csv(r"E:\Cursor_DATA\python_data\csv_data\datasets-session-22\expense_data.csv")

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
exp.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
print(ti.info())
print(ti.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
tip = sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
from streamlit import dataframe


x=tip.groupby('sex')
x['total_bill'].mean()
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\2176050017.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   x=tip.groupby('sex')
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
x=tip.groupby(['sex','smoker'])
x['total_bill'].mean().unstack()
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\3399678535.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   x=tip.groupby(['sex','smoker'])
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
tip.pivot_table(index='sex',columns='smoker',values='total_bill')
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\3598783443.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tip.pivot_table(index='sex',columns='smoker',values='total_bill')
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
tip.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum')
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\3059736937.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tip.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum')
# smoker      Yes       No
# sex
# Male    1337.07  1919.75
# Female   593.27   977.68

# %%
tip.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum',margins=True)
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\1719032394.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tip.pivot_table(index='sex',columns='smoker',values='total_bill',aggfunc='sum',margins=True)
# smoker      Yes       No      All
# sex
# Male    1337.07  1919.75  3256.82
# Female   593.27   977.68  1570.95
# All     1930.34  2897.43  4827.77

# %%
tip.pivot_table(index='sex', columns='smoker', values=['total_bill'])
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\1314979565.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tip.pivot_table(index='sex', columns='smoker', values=['total_bill'])
#        total_bill
# smoker        Yes         No
# sex
# Male    22.284500  19.791237
# Female  17.977879  18.105185

# %%
tip.pivot_table(index='sex', columns='smoker', values=['total_bill', 'tip', 'size'])['tip']
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\3338243856.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tip.pivot_table(index='sex', columns='smoker', values=['total_bill', 'tip', 'size'])['tip']
# smoker       Yes        No
# sex
# Male    3.051167  3.113402
# Female  2.931515  2.773519

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip.pivot_table(index=['sex','smoker'],columns=['day','time'],values='total_bill',aggfunc='sum',margins=True)
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\3625312359.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tip.pivot_table(index=['sex','smoker'],columns=['day','time'],values='total_bill',aggfunc='sum',margins=True)
# day               Thur           Fri           Sat            Sun           \
# time             Lunch Dinner  Lunch  Dinner Lunch   Dinner Lunch   Dinner
# sex    smoker
# Male   Yes      191.71   0.00  34.16  129.46   0.0   589.62   0.0   392.12
#        No       369.73   0.00   0.00   34.95   0.0   637.73   0.0   877.34
# Female Yes      134.53   0.00  39.78   48.80   0.0   304.00   0.0    66.16
#        No       381.58  18.78  15.98   22.75   0.0   247.05   0.0   291.54
# All            1077.55  18.78  89.92  235.96   NaN  1778.40   NaN  1627.16
#
# day                All
# time
# sex    smoker
# ...

# %%
tip.pivot_table(index=['sex','smoker'],columns=['day','time'],values=['total_bill','tip','size'],aggfunc={'size':sum,'total_bill':max,'tip':min},margins=True)
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\4275160954.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tip.pivot_table(index=['sex','smoker'],columns=['day','time'],values=['total_bill','tip','size'],aggfunc={'size':sum,'total_bill':max,'tip':min},margins=True)
# C:\Users\daayu\AppData\Local\Temp\ipykernel_2372\4275160954.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   tip.pivot_table(index=['sex','smoker'],columns=['day','time'],values=['total_bill','tip','size'],aggfunc={'size':sum,'total_bill':max,'tip':min},margins=True)
# ...

# %% [markdown]
# # for ploting graphs using pivot table

# %%
exp
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
exp.columns
# Out:
# Index(['Date', 'Account', 'Category', 'Subcategory', 'Note', 'INR',
#        'Income/Expense', 'Note.1', 'Amount', 'Currency', 'Account.1'],
#       dtype='object')

# %%
exp['Category'].shape
# Out:
# (277,)

# %%
p=exp.groupby('Category')
p.head()
# Out:
#                  Date               Account          Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment              Food          NaN
# 1      3/2/2022 10:11  CUB - online payment             Other          NaN
# 2      3/1/2022 19:50  CUB - online payment              Food          NaN
# 3      3/1/2022 18:56  CUB - online payment    Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment              Food          NaN
# 5      3/1/2022 18:22  CUB - online payment             Other          NaN
# 6      3/1/2022 18:21  CUB - online payment             Other          NaN
# 7     2/28/2022 11:56  CUB - online payment              Food          NaN
# 8     2/28/2022 11:45  CUB - online payment             Other          NaN
# 9     2/27/2022 15:29  CUB - online payment              Food          NaN
# 11    2/26/2022 17:37  CUB - online payment             Other          NaN
# ...

# %%
exp.set_index('Category')
# Out:
#                             Date               Account  Subcategory  \
# Category
# Food              3/2/2022 10:11  CUB - online payment          NaN
# Other             3/2/2022 10:11  CUB - online payment          NaN
# Food              3/1/2022 19:50  CUB - online payment          NaN
# Transportation    3/1/2022 18:56  CUB - online payment          NaN
# Food              3/1/2022 18:22  CUB - online payment          NaN
# ...                          ...                   ...          ...
# Food            11/22/2021 14:16  CUB - online payment          NaN
# Food            11/22/2021 14:16  CUB - online payment          NaN
# Transportation  11/21/2021 17:07  CUB - online payment          NaN
# Food            11/21/2021 15:50  CUB - online payment          NaN
# Other           11/21/2021 13:30  CUB - online payment          NaN
#
#                               Note     INR Income/Expense  Note.1  Amount  \
# Category
# ...

# %%
exp['Category'].value_counts()
# Out:
# Category
# Food                156
# Other                60
# Transportation       31
# Apparel               7
# Household             6
# Allowance             6
# Social Life           5
# Education             1
# Salary                1
# Self-development      1
# Beauty                1
# Gift                  1
# Petty cash            1
# Name: count, dtype: int64

# %%
exp.head()
# Out:
#              Date               Account        Category  Subcategory  \
# 0  3/2/2022 10:11  CUB - online payment            Food          NaN
# 1  3/2/2022 10:11  CUB - online payment           Other          NaN
# 2  3/1/2022 19:50  CUB - online payment            Food          NaN
# 3  3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4  3/1/2022 18:22  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
exp['Date'] = pd.to_datetime(exp['Date'])
exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    datetime64[ns]
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 23.9+ KB

# %%
exp['Date']
# Out:
# 0     2022-03-02 10:11:00
# 1     2022-03-02 10:11:00
# 2     2022-03-01 19:50:00
# 3     2022-03-01 18:56:00
# 4     2022-03-01 18:22:00
#               ...
# 272   2021-11-22 14:16:00
# 273   2021-11-22 14:16:00
# 274   2021-11-21 17:07:00
# 275   2021-11-21 15:50:00
# 276   2021-11-21 13:30:00
# Name: Date, Length: 277, dtype: datetime64[ns]

# %%
exp['Month']=exp['Date'].dt.month_name()

# %%
exp
# Out:
#                    Date               Account        Category  Subcategory  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1   2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2   2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4   2022-03-01 18:22:00  CUB - online payment            Food          NaN
# ..                  ...                   ...             ...          ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 273 2021-11-22 14:16:00  CUB - online payment            Food          NaN
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation          NaN
# 275 2021-11-21 15:50:00  CUB - online payment            Food          NaN
# 276 2021-11-21 13:30:00  CUB - online payment           Other          NaN
#
# ...

# %%
exp.pivot_table(index='Month',columns='Category',values='Amount',aggfunc='sum',fill_value=0)
# Out:
# Category  Allowance  Apparel  Beauty  Education     Food   Gift  Household  \
# Month
# December    11000.0   2590.0   196.0        0.0  5335.00    0.0     4800.0
# February        0.0    798.0     0.0        0.0  5579.85    0.0     2808.0
# January      1000.0      0.0     0.0     1400.0  9112.51    0.0     4580.0
# March           0.0      0.0     0.0        0.0   195.00    0.0        0.0
# November     2000.0      0.0     0.0        0.0  3174.40  115.0        0.0
#
# Category    Other  Petty cash  Salary  Self-development  Social Life  \
# Month
# December   1790.0         0.0     0.0             400.0       513.72
# February  20000.0         0.0     0.0               0.0      1800.00
# January   13178.0         0.0  8000.0               0.0       200.00
# March       900.0         0.0     0.0               0.0         0.00
# November   2000.0         3.0     0.0               0.0         0.00
#
# Category  Transportation
# Month
# December           914.0
# ...

# %%
exp.pivot_table(index='Month',columns='Category',values='Amount',aggfunc='sum',fill_value=0).plot()
# Out:
# <Axes: xlabel='Month'>
