# %% [markdown]
# ## time stamp dataset in pndas

# %%
import pandas as pd

# %%
pd.Timestamp("20/9/2025")
# Out:
# Timestamp('2025-09-20 00:00:00')

# %%
pd.Timestamp("20/9/2025 07:20")
# Out:
# Timestamp('2025-09-20 07:20:00')

# %%
x=pd.Timestamp("20/9/2025 07:20pm")
x
# Out:
# Timestamp('2025-09-20 19:20:00')

# %%
print(type(x))
print(x.year)
print(x.month)
print(x.day)
print(x.hour)
x
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2025
# 9
# 20
# 19
# Timestamp('2025-09-20 19:20:00')

# %%
# datetime module in python
import datetime as dt
dt.datetime(2025,12,12,19,10)
# Out:
# datetime.datetime(2025, 12, 12, 19, 10)

# %%
pd.Timestamp(dt.datetime(2025,12,12,19,10))
# Out:
# Timestamp('2025-12-12 19:10:00')

# %%
pd.Timestamp(2015/12/12)
# Out:
# Timestamp('1970-01-01 00:00:00.000000013')

# %%
# for Datetimeindex example
pd.DatetimeIndex(["2025-12-12","2024-11-11","2023-10-10"])
# Out:
# DatetimeIndex(['2025-12-12', '2024-11-11', '2023-10-10'], dtype='datetime64[ns]', freq=None)

# %%
# example of Datetimeindex in series as index
s=pd.Series([10,20,30],index=pd.DatetimeIndex(["2025-12-12","2024-11-11","2023-10-10"]))
s
# Out:
# 2025-12-12    10
# 2024-11-11    20
# 2023-10-10    30
# dtype: int64

# %%
# example of data_range 
pd.date_range("2023-01-01",periods=10,freq="D")
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
# example of data_range 
pd.date_range("2023-01-01",end="2025/10/2",freq="D")
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2025-09-23', '2025-09-24', '2025-09-25', '2025-09-26',
#                '2025-09-27', '2025-09-28', '2025-09-29', '2025-09-30',
#                '2025-10-01', '2025-10-02'],
#               dtype='datetime64[ns]', length=1006, freq='D')

# %%
pd.date_range("2023-01-01",end="2025/10/2",freq="B")#for business days
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#                '2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11',
#                '2023-01-12', '2023-01-13',
#                ...
#                '2025-09-19', '2025-09-22', '2025-09-23', '2025-09-24',
#                '2025-09-25', '2025-09-26', '2025-09-29', '2025-09-30',
#                '2025-10-01', '2025-10-02'],
#               dtype='datetime64[ns]', length=719, freq='B')

# %%
pd.date_range("2023-01-01",end="2025/10/2",freq="W")
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-08', '2023-01-15', '2023-01-22',
#                '2023-01-29', '2023-02-05', '2023-02-12', '2023-02-19',
#                '2023-02-26', '2023-03-05',
#                ...
#                '2025-07-27', '2025-08-03', '2025-08-10', '2025-08-17',
#                '2025-08-24', '2025-08-31', '2025-09-07', '2025-09-14',
#                '2025-09-21', '2025-09-28'],
#               dtype='datetime64[ns]', length=144, freq='W-SUN')

# %%
# hourly
pd.date_range("2025-09-20",end="2025/09/30",freq="H")
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_23800\540329003.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range("2025-09-20",end="2025/09/30",freq="H")
# DatetimeIndex(['2025-09-20 00:00:00', '2025-09-20 01:00:00',
#                '2025-09-20 02:00:00', '2025-09-20 03:00:00',
#                '2025-09-20 04:00:00', '2025-09-20 05:00:00',
#                '2025-09-20 06:00:00', '2025-09-20 07:00:00',
#                '2025-09-20 08:00:00', '2025-09-20 09:00:00',
#                ...
#                '2025-09-29 15:00:00', '2025-09-29 16:00:00',
#                '2025-09-29 17:00:00', '2025-09-29 18:00:00',
#                '2025-09-29 19:00:00', '2025-09-29 20:00:00',
#                '2025-09-29 21:00:00', '2025-09-29 22:00:00',
#                '2025-09-29 23:00:00', '2025-09-30 00:00:00'],
#               dtype='datetime64[ns]', length=241, freq='h')

# %%
pd.date_range("2025-09-20",end="2025/09/30",freq="6H")
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_23800\350364610.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   pd.date_range("2025-09-20",end="2025/09/30",freq="6H")
# DatetimeIndex(['2025-09-20 00:00:00', '2025-09-20 06:00:00',
#                '2025-09-20 12:00:00', '2025-09-20 18:00:00',
#                '2025-09-21 00:00:00', '2025-09-21 06:00:00',
#                '2025-09-21 12:00:00', '2025-09-21 18:00:00',
#                '2025-09-22 00:00:00', '2025-09-22 06:00:00',
#                '2025-09-22 12:00:00', '2025-09-22 18:00:00',
#                '2025-09-23 00:00:00', '2025-09-23 06:00:00',
#                '2025-09-23 12:00:00', '2025-09-23 18:00:00',
#                '2025-09-24 00:00:00', '2025-09-24 06:00:00',
#                '2025-09-24 12:00:00', '2025-09-24 18:00:00',
#                '2025-09-25 00:00:00', '2025-09-25 06:00:00',
#                '2025-09-25 12:00:00', '2025-09-25 18:00:00',
# ...

# %%
pd.date_range("2023-01-01",end="2025/10/2",freq="M")
# Out:
# C:\Users\daayu\AppData\Local\Temp\ipykernel_23800\334404711.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   pd.date_range("2023-01-01",end="2025/10/2",freq="M")
# DatetimeIndex(['2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#                '2025-09-30'],
#               dtype='datetime64[ns]', freq='ME')

# %%
mid_month = pd.date_range("2023-01-01", end="2025/10/2", freq="MS") + pd.Timedelta(days=14)
mid_month
# Out:
# DatetimeIndex(['2023-01-15', '2023-02-15', '2023-03-15', '2023-04-15',
#                '2023-05-15', '2023-06-15', '2023-07-15', '2023-08-15',
#                '2023-09-15', '2023-10-15', '2023-11-15', '2023-12-15',
#                '2024-01-15', '2024-02-15', '2024-03-15', '2024-04-15',
#                '2024-05-15', '2024-06-15', '2024-07-15', '2024-08-15',
#                '2024-09-15', '2024-10-15', '2024-11-15', '2024-12-15',
#                '2025-01-15', '2025-02-15', '2025-03-15', '2025-04-15',
#                '2025-05-15', '2025-06-15', '2025-07-15', '2025-08-15',
#                '2025-09-15', '2025-10-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
ti=pd.read_csv(r'E:\Cursor_DATA\python_data\csv_data\datasets-session-22\titanic.csv')
exp=pd.read_csv(r"E:\Cursor_DATA\python_data\csv_data\datasets-session-22\expense_data.csv")

# %%
ti.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
exp
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
exp['Date']
# Out:
# 0        3/2/2022 10:11
# 1        3/2/2022 10:11
# 2        3/1/2022 19:50
# 3        3/1/2022 18:56
# 4        3/1/2022 18:22
#              ...
# 272    11/22/2021 14:16
# 273    11/22/2021 14:16
# 274    11/21/2021 17:07
# 275    11/21/2021 15:50
# 276    11/21/2021 13:30
# Name: Date, Length: 277, dtype: object

# %%
exp['Date'].str.split().str.get(0)
# Out:
# 0        3/2/2022
# 1        3/2/2022
# 2        3/1/2022
# 3        3/1/2022
# 4        3/1/2022
#           ...
# 272    11/22/2021
# 273    11/22/2021
# 274    11/21/2021
# 275    11/21/2021
# 276    11/21/2021
# Name: Date, Length: 277, dtype: object

# %%
exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
exp.describe()
# Out:
#        Subcategory           INR  Note.1        Amount     Account.1
# count          0.0    277.000000     0.0    277.000000    277.000000
# mean           NaN    410.750903     NaN    406.759134    406.759134
# std            NaN   1065.756569     NaN   1065.158318   1065.158318
# min            NaN      3.000000     NaN      3.000000      3.000000
# 25%            NaN     50.000000     NaN     50.000000     50.000000
# 50%            NaN    128.000000     NaN    125.000000    125.000000
# 75%            NaN    301.150000     NaN    300.000000    300.000000
# max            NaN  10000.000000     NaN  10000.000000  10000.000000

# %%
pd.to_datetime(exp['Date'])
# Out:
# 0     2022-03-02 10:11:00
# 1     2022-03-02 10:11:00
# 2     2022-03-01 19:50:00
# 3     2022-03-01 18:56:00
# 4     2022-03-01 18:22:00
#               ...
# 272   2021-11-22 14:16:00
# 273   2021-11-22 14:16:00
# 274   2021-11-21 17:07:00
# 275   2021-11-21 15:50:00
# 276   2021-11-21 13:30:00
# Name: Date, Length: 277, dtype: datetime64[ns]

# %%
pd.to_datetime(exp['Date']).dt.month_name()
# Out:
# 0         March
# 1         March
# 2         March
# 3         March
# 4         March
#          ...
# 272    November
# 273    November
# 274    November
# 275    November
# 276    November
# Name: Date, Length: 277, dtype: object

# %%
exp.head()
# Out:
#                  Date               Account        Category  Subcategory  \
# 0 2022-03-02 10:11:00  CUB - online payment            Food          NaN
# 1 2022-03-02 10:11:00  CUB - online payment           Other          NaN
# 2 2022-03-01 19:50:00  CUB - online payment            Food          NaN
# 3 2022-03-01 18:56:00  CUB - online payment  Transportation          NaN
# 4 2022-03-01 18:22:00  CUB - online payment            Food          NaN
#
#                Note    INR Income/Expense  Note.1  Amount Currency  Account.1
# 0           Brownie   50.0        Expense     NaN    50.0      INR       50.0
# 1  To lended people  300.0        Expense     NaN   300.0      INR      300.0
# 2            Dinner   78.0        Expense     NaN    78.0      INR       78.0
# 3             Metro   30.0        Expense     NaN    30.0      INR       30.0
# 4            Snacks   67.0        Expense     NaN    67.0      INR       67.0

# %%
exp['Date']=pd.to_datetime(exp['Date'])
exp.drop(columns='Subcategory',inplace=True)
exp
# Out:
#                    Date               Account        Category  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food
# 1   2022-03-02 10:11:00  CUB - online payment           Other
# 2   2022-03-01 19:50:00  CUB - online payment            Food
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation
# 4   2022-03-01 18:22:00  CUB - online payment            Food
# ..                  ...                   ...             ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food
# 273 2021-11-22 14:16:00  CUB - online payment            Food
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation
# 275 2021-11-21 15:50:00  CUB - online payment            Food
# 276 2021-11-21 13:30:00  CUB - online payment           Other
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# 0               Brownie    50.0        Expense     NaN    50.0      INR
# 1      To lended people   300.0        Expense     NaN   300.0      INR
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(exp['Date'],exp['INR'])

# %%
exp['Day']=pd.to_datetime(exp['Date']).dt.day_name()

# %%
exp
# Out:
#                    Date               Account        Category  \
# 0   2022-03-02 10:11:00  CUB - online payment            Food
# 1   2022-03-02 10:11:00  CUB - online payment           Other
# 2   2022-03-01 19:50:00  CUB - online payment            Food
# 3   2022-03-01 18:56:00  CUB - online payment  Transportation
# 4   2022-03-01 18:22:00  CUB - online payment            Food
# ..                  ...                   ...             ...
# 272 2021-11-22 14:16:00  CUB - online payment            Food
# 273 2021-11-22 14:16:00  CUB - online payment            Food
# 274 2021-11-21 17:07:00  CUB - online payment  Transportation
# 275 2021-11-21 15:50:00  CUB - online payment            Food
# 276 2021-11-21 13:30:00  CUB - online payment           Other
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# 0               Brownie    50.0        Expense     NaN    50.0      INR
# 1      To lended people   300.0        Expense     NaN   300.0      INR
# ...

# %%
exp.groupby('Day')["INR"].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Day'>

# %%
exp.groupby('Month')["INR"].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>
