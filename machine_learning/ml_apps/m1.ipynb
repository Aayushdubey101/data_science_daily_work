# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tensor=np.array([11,25])
tensor
# Out:
# array([11, 25])

# %%
tensor.ndim
# Out:
# 1

# %%
tensor.shape
# Out:
# (2,)

# %%
tensor.dtype
# Out:
# dtype('int64')

# %%
tensor =np.array([[1,2],
             [3,4],
             [5,6]])
tensor
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
tensor.shape
# Out:
# (3, 2)

# %%
tensor.ndim
# Out:
# 2

# %%
tensor.shape
# Out:
# (3, 2)

# %%
tensor.size
# Out:
# 6
